# %%
import sqlite3
import os
import time

# Define database file and data directory
DB_WTHR_FILE = "new_weather_data.db"
DATA_DIR = "../wx_data"

# Function to Create table if not exists Using SQLite 3 Connection Object
def create_table():
    conn = sqlite3.connect(DB_WTHR_FILE)
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS new_weather_data (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            station_id TEXT NOT NULL,
            date TEXT CHECK (length(date) = 8) NOT NULL,
            max_temp INTEGER CHECK (max_temp >= -9999),
            min_temp INTEGER CHECK (min_temp >= -9999),
            precipitation INTEGER CHECK (precipitation >= -9999),
            UNIQUE (station_id, date)
        );
    """)
    conn.commit()
    conn.close()
    print("Table created successfully (if not already exists).")

# Run this function
create_table()
# Out:
# Table created successfully (if not already exists).

# %%
def insert_data(file_path):
    conn = sqlite3.connect(DB_WTHR_FILE)
    cursor = conn.cursor()
    
    # Extract station ID from filename
    station_id = os.path.basename(file_path).split('.')[0]  
    inserted_count = 0
    
    with open(file_path, "r") as file:
        for line in file:
            parts = line.strip().split("\t")
            if len(parts) != 4:
                continue  # Skip invalid lines
            
            date, max_temp, min_temp, precipitation = parts
            
            # Handle malformed data
            try:
                max_temp, min_temp, precipitation = int(max_temp), int(min_temp), int(precipitation)
            except ValueError:
                continue
            
            # Insert data with exception handling for duplicates
            try:
                cursor.execute("""
                    INSERT INTO new_weather_data (station_id, date, max_temp, min_temp, precipitation)
                    VALUES (?, ?, ?, ?, ?)
                """, (station_id, date, max_temp, min_temp, precipitation))
                inserted_count += 1
            except sqlite3.IntegrityError:
                continue  # Skip duplicates

    conn.commit()
    conn.close()
    print(f"{inserted_count} records inserted from {os.path.basename(file_path)}")
    return inserted_count

# %%
def process_all_files():
    start_time = time.time()
    total_inserted = 0

    print("Data ingestion started...\n")
    
    if not os.path.exists(DATA_DIR):
        print(f"Data directory '{DATA_DIR}' not found. Please check the path.")
        return

    files = [f for f in os.listdir(DATA_DIR) if os.path.isfile(os.path.join(DATA_DIR, f))]
    
    if not files:
        print("No files found in the data directory.")
        return
    
    for filename in files:
        file_path = os.path.join(DATA_DIR, filename)
        print(f"Processing {filename}...")
        inserted_count = insert_data(file_path)
        total_inserted += inserted_count
    
    end_time = time.time()
    print("\n Data ingestion completed.")
    print(f"Total time taken: {end_time - start_time:.2f} seconds.")
    print(f"Total records inserted: {total_inserted}")

# Run the data ingestion process
process_all_files()
# Out:
# Data ingestion started...
#
# Processing USC00257715.txt...
# 10957 records inserted from USC00257715.txt
# Processing USC00113879.txt...
# 9074 records inserted from USC00113879.txt
# Processing USC00127935.txt...
# 10380 records inserted from USC00127935.txt
# Processing USC00112193.txt...
# 10653 records inserted from USC00112193.txt
# Processing USC00250640.txt...
# 10957 records inserted from USC00250640.txt
# Processing USC00257070.txt...
# 10926 records inserted from USC00257070.txt
# Processing USC00114442.txt...
# 10957 records inserted from USC00114442.txt
# Processing USC00115833.txt...
# 10866 records inserted from USC00115833.txt
# Processing USC00130133.txt...
# 10957 records inserted from USC00130133.txt
# Processing USC00132724.txt...
# 10836 records inserted from USC00132724.txt
# Processing USC00250130.txt...
# 9587 records inserted from USC00250130.txt
# Processing USC00256970.txt...
# 10017 records inserted from USC00256970.txt
# Processing USC00116446.txt...
# 10654 records inserted from USC00116446.txt
# Processing USC00253175.txt...
# 10957 records inserted from USC00253175.txt
# Processing USC00129113.txt...
# 10927 records inserted from USC00129113.txt
# Processing USC00134142.txt...
# 10807 records inserted from USC00134142.txt
# Processing USC00121229.txt...
# 6087 records inserted from USC00121229.txt
# Processing USC00116526.txt...
# 10926 records inserted from USC00116526.txt
# Processing USC00259510.txt...
# 8735 records inserted from USC00259510.txt
# Processing USC00255470.txt...
# 8489 records inserted from USC00255470.txt
# Processing USC00257515.txt...
# 10075 records inserted from USC00257515.txt
# Processing USC00258395.txt...
# 10957 records inserted from USC00258395.txt
# Processing USC00338313.txt...
# 9862 records inserted from USC00338313.txt
# Processing USC00131402.txt...
# 10957 records inserted from USC00131402.txt
# Processing USC00118916.txt...
# 10865 records inserted from USC00118916.txt
# Processing USC00124181.txt...
# 10681 records inserted from USC00124181.txt
# Processing USC00128036.txt...
# 10835 records inserted from USC00128036.txt
# Processing USC00126580.txt...
# 10899 records inserted from USC00126580.txt
# Processing USC00129670.txt...
# 10957 records inserted from USC00129670.txt
# Processing USC00115943.txt...
# 10957 records inserted from USC00115943.txt
# Processing USC00124008.txt...
# 5476 records inserted from USC00124008.txt
# Processing USC00116910.txt...
# 10898 records inserted from USC00116910.txt
# Processing USC00114108.txt...
# 10896 records inserted from USC00114108.txt
# Processing USC00127298.txt...
# 10957 records inserted from USC00127298.txt
# Processing USC00110187.txt...
# 10407 records inserted from USC00110187.txt
# Processing USC00253365.txt...
# 10926 records inserted from USC00253365.txt
# Processing USC00251200.txt...
# 10805 records inserted from USC00251200.txt
# Processing USC00112140.txt...
# 10957 records inserted from USC00112140.txt
# Processing USC00253615.txt...
# 10927 records inserted from USC00253615.txt
# Processing USC00255310.txt...
# 10926 records inserted from USC00255310.txt
# Processing USC00132864.txt...
# 10957 records inserted from USC00132864.txt
# Processing USC00129511.txt...
# 6849 records inserted from USC00129511.txt
# Processing USC00118740.txt...
# 10957 records inserted from USC00118740.txt
# Processing USC00333780.txt...
# 10927 records inserted from USC00333780.txt
# Processing USC00254900.txt...
# 10927 records inserted from USC00254900.txt
# Processing USC00255565.txt...
# 10957 records inserted from USC00255565.txt
# Processing USC00250435.txt...
# 10957 records inserted from USC00250435.txt
# Processing USC00252020.txt...
# 10746 records inserted from USC00252020.txt
# Processing USC00138296.txt...
# 10837 records inserted from USC00138296.txt
# Processing USC00132977.txt...
# 10957 records inserted from USC00132977.txt
# Processing USC00118147.txt...
# 9896 records inserted from USC00118147.txt
# Processing USC00250622.txt...
# 10896 records inserted from USC00250622.txt
# Processing USC00331592.txt...
# 10957 records inserted from USC00331592.txt
# Processing USC00258915.txt...
# 10957 records inserted from USC00258915.txt
# Processing USC00250420.txt...
# 10379 records inserted from USC00250420.txt
# Processing USC00338830.txt...
# 10957 records inserted from USC00338830.txt
# Processing USC00115515.txt...
# 6271 records inserted from USC00115515.txt
# Processing USC00120784.txt...
# 10897 records inserted from USC00120784.txt
# Processing USC00112483.txt...
# 10898 records inserted from USC00112483.txt
# Processing USC00332098.txt...
# 10927 records inserted from USC00332098.txt
# Processing USC00116579.txt...
# 10407 records inserted from USC00116579.txt
# Processing USC00137979.txt...
# 10926 records inserted from USC00137979.txt
# Processing USC00258480.txt...
# 10808 records inserted from USC00258480.txt
# Processing USC00258133.txt...
# 9225 records inserted from USC00258133.txt
# Processing USC00115712.txt...
# 10957 records inserted from USC00115712.txt
# Processing USC00331152.txt...
# 8886 records inserted from USC00331152.txt
# Processing USC00335297.txt...
# 9557 records inserted from USC00335297.txt
# Processing USC00334189.txt...
# 10834 records inserted from USC00334189.txt
# Processing USC00253660.txt...
# 10896 records inserted from USC00253660.txt
# Processing USC00137161.txt...
# 10957 records inserted from USC00137161.txt
# Processing USC00336600.txt...
# 10561 records inserted from USC00336600.txt
# Processing USC00253715.txt...
# 8521 records inserted from USC00253715.txt
# Processing USC00338822.txt...
# 10957 records inserted from USC00338822.txt
# Processing USC00256135.txt...
# 10957 records inserted from USC00256135.txt
# Processing USC00254440.txt...
# 10866 records inserted from USC00254440.txt
# Processing USC00132999.txt...
# 10804 records inserted from USC00132999.txt
# Processing USC00335041.txt...
# 10896 records inserted from USC00335041.txt
# Processing USC00331541.txt...
# 10957 records inserted from USC00331541.txt
# Processing USC00135952.txt...
# 10899 records inserted from USC00135952.txt
# Processing USC00256040.txt...
# 9009 records inserted from USC00256040.txt
# Processing USC00134735.txt...
# 10928 records inserted from USC00134735.txt
# Processing USC00123513.txt...
# 10347 records inserted from USC00123513.txt
# Processing USC00129557.txt...
# 10957 records inserted from USC00129557.txt
# Processing USC00114198.txt...
# 10926 records inserted from USC00114198.txt
# Processing USC00252820.txt...
# 10896 records inserted from USC00252820.txt
# Processing USC00120177.txt...
# 10837 records inserted from USC00120177.txt
# Processing USC00134894.txt...
# 10867 records inserted from USC00134894.txt
# Processing USC00130600.txt...
# 10928 records inserted from USC00130600.txt
# Processing USC00137147.txt...
# 10957 records inserted from USC00137147.txt
# Processing USC00116610.txt...
# 10957 records inserted from USC00116610.txt
# Processing USC00126705.txt...
# 10598 records inserted from USC00126705.txt
# Processing USC00339312.txt...
# 10957 records inserted from USC00339312.txt
# Processing USC00336196.txt...
# 10957 records inserted from USC00336196.txt
# Processing USC00134063.txt...
# 10714 records inserted from USC00134063.txt
# Processing USC00332119.txt...
# 5722 records inserted from USC00332119.txt
# Processing USC00120200.txt...
# 10927 records inserted from USC00120200.txt
# Processing USC00258465.txt...
# 10684 records inserted from USC00258465.txt
# Processing USC00115326.txt...
# 10077 records inserted from USC00115326.txt
# Processing USC00338769.txt...
# 10957 records inserted from USC00338769.txt
# Processing USC00116558.txt...
# 10804 records inserted from USC00116558.txt
# Processing USC00115079.txt...
# 10501 records inserted from USC00115079.txt
# Processing USC00253735.txt...
# 10868 records inserted from USC00253735.txt
# Processing USC00333758.txt...
# 10712 records inserted from USC00333758.txt
# Processing USC00335315.txt...
# 9768 records inserted from USC00335315.txt
# Processing USC00252205.txt...
# 10926 records inserted from USC00252205.txt
# Processing USC00125237.txt...
# 10865 records inserted from USC00125237.txt
# Processing USC00333375.txt...
# 10926 records inserted from USC00333375.txt
# Processing USC00338552.txt...
# 10896 records inserted from USC00338552.txt
# Processing USC00132789.txt...
# 10957 records inserted from USC00132789.txt
# Processing USC00250375.txt...
# 10835 records inserted from USC00250375.txt
# Processing USC00138688.txt...
# 10957 records inserted from USC00138688.txt
# Processing USC00115901.txt...
# 10957 records inserted from USC00115901.txt
# Processing USC00122149.txt...
# 9554 records inserted from USC00122149.txt
# Processing USC00114823.txt...
# 10929 records inserted from USC00114823.txt
# Processing USC00110338.txt...
# 10712 records inserted from USC00110338.txt
# Processing USC00121873.txt...
# 10742 records inserted from USC00121873.txt
# Processing USC00123527.txt...
# 10896 records inserted from USC00123527.txt
# Processing USC00127755.txt...
# 8467 records inserted from USC00127755.txt
# Processing USC00111436.txt...
# 10744 records inserted from USC00111436.txt
# Processing USC00110072.txt...
# 10865 records inserted from USC00110072.txt
# Processing USC00131533.txt...
# 10957 records inserted from USC00131533.txt
# Processing USC00135769.txt...
# 10833 records inserted from USC00135769.txt
# Processing USC00135796.txt...
# 10957 records inserted from USC00135796.txt
# Processing USC00119241.txt...
# 10869 records inserted from USC00119241.txt
# Processing USC00336781.txt...
# 10927 records inserted from USC00336781.txt
# Processing USC00254110.txt...
# 10683 records inserted from USC00254110.txt
# Processing USC00253910.txt...
# 10957 records inserted from USC00253910.txt
# Processing USC00253630.txt...
# 10927 records inserted from USC00253630.txt
# Processing USC00126001.txt...
# 10562 records inserted from USC00126001.txt
# Processing USC00255080.txt...
# 9556 records inserted from USC00255080.txt
# Processing USC00117551.txt...
# 10803 records inserted from USC00117551.txt
# Processing USC00121747.txt...
# 10957 records inserted from USC00121747.txt
# Processing USC00127875.txt...
# 8219 records inserted from USC00127875.txt
# Processing USC00127646.txt...
# 10957 records inserted from USC00127646.txt
# Processing USC00111280.txt...
# 9343 records inserted from USC00111280.txt
# Processing USC00121425.txt...
# 5811 records inserted from USC00121425.txt
# Processing USC00129253.txt...
# 10468 records inserted from USC00129253.txt
# Processing USC00250070.txt...
# 8918 records inserted from USC00250070.txt
# Processing USC00252840.txt...
# 9771 records inserted from USC00252840.txt
# Processing USC00116738.txt...
# 8126 records inserted from USC00116738.txt
# Processing USC00253035.txt...
# 2069 records inserted from USC00253035.txt
# Processing USC00130112.txt...
# 10806 records inserted from USC00130112.txt
# Processing USC00338534.txt...
# 10469 records inserted from USC00338534.txt
# Processing USC00115768.txt...
# 10745 records inserted from USC00115768.txt
# Processing USC00131635.txt...
# 10957 records inserted from USC00131635.txt
# Processing USC00251145.txt...
# 10836 records inserted from USC00251145.txt
# Processing USC00252100.txt...
# 10713 records inserted from USC00252100.txt
# Processing USC00119354.txt...
# 10896 records inserted from USC00119354.txt
# Processing USC00113335.txt...
# 10652 records inserted from USC00113335.txt
# Processing USC00256570.txt...
# 10836 records inserted from USC00256570.txt
# Processing USC00124837.txt...
# 10866 records inserted from USC00124837.txt
# Processing USC00112348.txt...
# 9681 records inserted from USC00112348.txt
# Processing USC00332791.txt...
# 10957 records inserted from USC00332791.txt
# Processing USC00336118.txt...
# 10957 records inserted from USC00336118.txt
# Processing USC00129080.txt...
# 7609 records inserted from USC00129080.txt
# Processing USC00127522.txt...
# 10926 records inserted from USC00127522.txt
# Processing USC00125337.txt...
# 10926 records inserted from USC00125337.txt
# Processing USC00123418.txt...
# 10957 records inserted from USC00123418.txt
# Processing USC00127482.txt...
# 10957 records inserted from USC00127482.txt
# Processing USC00121030.txt...
# 10135 records inserted from USC00121030.txt
# Processing USC00253185.txt...
# 10957 records inserted from USC00253185.txt
# Processing USC00331072.txt...
# 10957 records inserted from USC00331072.txt
# Processing USC00120676.txt...
# 10652 records inserted from USC00120676.txt
# Processing USC00127125.txt...
# 10804 records inserted from USC00127125.txt
# Processing USC00331890.txt...
# 10772 records inserted from USC00331890.txt
# Processing USC00254985.txt...
# 9861 records inserted from USC00254985.txt
# Processing USC00259090.txt...
# 9374 records inserted from USC00259090.txt
#
#  Data ingestion completed.
# Total time taken: 3.30 seconds.
# Total records inserted: 1729957

# %%
def fetch_sample_records(limit=10):
    conn = sqlite3.connect(DB_WTHR_FILE)
    cursor = conn.cursor()
    cursor.execute(f"SELECT * FROM new_weather_data LIMIT {limit}")
    records = cursor.fetchall()
    conn.close()
    
    print(f"Showing {limit} sample records:\n")
    for row in records:
        print(row)

# Run this to check the inserted data
fetch_sample_records()
# Out:
# Showing 10 sample records:
#
# (1, 'USC00257715', '19850101', -83, -144, 0)
# (2, 'USC00257715', '19850102', 0, -133, 0)
# (3, 'USC00257715', '19850103', 22, -111, 0)
# (4, 'USC00257715', '19850104', 61, -50, 0)
# (5, 'USC00257715', '19850105', 78, -67, 0)
# (6, 'USC00257715', '19850106', 94, -11, 0)
# (7, 'USC00257715', '19850107', 56, -11, 0)
# (8, 'USC00257715', '19850108', 17, -89, 0)
# (9, 'USC00257715', '19850109', -50, -94, 33)
# (10, 'USC00257715', '19850110', -61, -106, 41)

# %%
def count_total_records():
    conn = sqlite3.connect(DB_WTHR_FILE)
    cursor = conn.cursor()
    cursor.execute("SELECT COUNT(*) FROM new_weather_data")
    total_records = cursor.fetchone()[0]
    conn.close()
    print(f"Total records in database: {total_records}")

# Run this function
count_total_records()
# Out:
# Total records in database: 1729957
